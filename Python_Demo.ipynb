# %% [markdown]
# <a href="https://colab.research.google.com/github/parnapallichandrakanth/Python-Codes/blob/main/Python_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi")
# Out:
# Hi
